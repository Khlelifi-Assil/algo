# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

class CollaborativeFilteringRecommendation:
    def __init__(self, k_neighbors=5):
        self.k_neighbors = k_neighbors
        self.knn = KNeighborsClassifier(n_neighbors=k_neighbors, metric='cosine')
        self.svm = SVC(kernel='linear')  # Initialize SVM classifier
        self.is_trained = False

    # ... (Rest of your class code remains the same)

    def train_model(self):
        X_train = self.train_data[['Age', 'Region', 'Category', 'genre']]
        y_train = self.train_data['Rate']
        
        # Train KNN model
        self.knn.fit(X_train, y_train)
        
        # Train SVM model
        self.svm.fit(X_train, y_train)
        
        self.is_trained = True

    def evaluate_model(self):
        if not self.is_trained:
            print("Model is not trained. Call train_model() first.")
            return

        X_test = self.test_data[['Age', 'Region', 'Category', 'genre']]
        y_true = self.test_data['Rate']
        
        # Predict using KNN
        y_pred_knn = self.knn.predict(X_test)

        # Predict using SVM
        y_pred_svm = self.svm.predict(X_test)

        print("KNN Classification Report:")
        print(classification_report(y_true, y_pred_knn))
        print("KNN Confusion Matrix:")
        print(confusion_matrix(y_true, y_pred_knn))

        print("\nSVM Classification Report:")
        print(classification_report(y_true, y_pred_svm))
        print("SVM Confusion Matrix:")
        print(confusion_matrix(y_true, y_pred_svm))

# Example usage:
if __name__ == "__main__":
    cf_recommendation = CollaborativeFilteringRecommendation()
    cf_recommendation.load_data('customers.json', 'products.json', 'ratings.json')
    cf_recommendation.preprocess_data()
    cf_recommendation.train_model()
    cf_recommendation.evaluate_model()
